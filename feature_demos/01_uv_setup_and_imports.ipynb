# %% [markdown]
# # 01 - UV Setup and Imports
#
# **Purpose:** This notebook sets up the Python environment using `uv` package manager and verifies all required dependencies for the AgriTwin-GH digital twin system.
#
# **What it produces:**
# - Virtual environment with all required packages
# - Verification that all imports work correctly
# - Version information for reproducibility
#
# **Key packages:**
# - numpy, pandas: Data manipulation
# - matplotlib, plotly: Visualization
# - scikit-learn: ML for growth stage classification
# - ipywidgets: Interactive controls (optional)
# - scipy, statsmodels: Statistics and time-series modeling

# %% [markdown]
# ## Step 1: Install Required Packages with UV
#
# We use `uv` for fast, reliable package management. The packages will be installed into the current Jupyter kernel's Python environment.

# %%
# Install all required packages using uv
# This installs into the current Python environment that the Jupyter kernel is using
import sys
# !{sys.executable} -m pip install uv
# !{sys.executable} -m uv pip install numpy pandas matplotlib plotly scikit-learn scipy statsmodels ipywidgets seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 29.7 MB/s  0:00:00m0:00:010:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Using Python 3.12.1 environment at: /usr/local/python/3.12.1
# Resolved 41 packages in 556ms
# Installed 41 packages in 1.77s
#  + asttokens==3.0.1
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + decorator==5.2.1
#  + executing==2.2.1
#  + fonttools==4.61.1
#  + ipython==9.10.0
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.8
#  + jedi==0.19.2
#  + joblib==1.5.3
#  + jupyterlab-widgets==3.0.16
#  + kiwisolver==1.4.9
#  + matplotlib==3.10.8
#  + matplotlib-inline==0.2.1
#  + narwhals==2.16.0
#  + numpy==2.4.2
#  + packaging==26.0
#  + pandas==3.0.0
#  + parso==0.8.6
#  + patsy==1.0.2
#  + pexpect==4.9.0
#  + pillow==12.1.1
#  + plotly==6.5.2
#  + prompt-toolkit==3.0.52
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pygments==2.19.2
# ...

# %% [markdown]
# ## Step 2: Verify Installation
#
# Check that packages were installed successfully.

# %% [markdown]
# ## Step 3: Import All Required Packages
#
# Test that all packages are installed correctly and display version information.

# %%
# Import all required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LinearRegression
from scipy import signal, interpolate
from scipy.stats import norm
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import seaborn as sns
from datetime import datetime, timedelta
import warnings
import os
import json

warnings.filterwarnings('ignore')

print("✓ All imports successful!")
print("\n" + "="*60)
print("Package Versions (for reproducibility):")
print("="*60)
print(f"NumPy:         {np.__version__}")
print(f"Pandas:        {pd.__version__}")
print(f"Matplotlib:    {plt.matplotlib.__version__}")
print(f"Plotly:        {px.__version__}")
print(f"Scikit-learn:  {sklearn.__version__}")
print(f"SciPy:         {scipy.__version__}")
print(f"Statsmodels:   {sm.__version__}")
print(f"Seaborn:       {sns.__version__}")
print("="*60)
# Out:
# ✓ All imports successful!
#
# ...
# Package Versions (for reproducibility):
# ...
# NumPy:         2.4.2
# Pandas:        3.0.0
# Matplotlib:    3.10.8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 32
#      30 print(f"Pandas:        {pd.__version__}")
#      31 print(f"Matplotlib:    {plt.matplotlib.__version__}")
# ---> 32 print(f"Plotly:        {px.__version__}")
#      33 print(f"Scikit-learn:  {sklearn.__version__}")
#      34 print(f"SciPy:         {scipy.__version__}")
#
# AttributeError: module 'plotly.express' has no attribute '__version__'

# %%
import sklearn
import scipy

# %% [markdown]
# ## Step 4: Configure Plotting Defaults
#
# Set up consistent, publication-ready plotting styles.

# %%
# Matplotlib configuration for report-ready figures
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['xtick.labelsize'] = 9
plt.rcParams['ytick.labelsize'] = 9
plt.rcParams['legend.fontsize'] = 9
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3

# Set seaborn style
sns.set_style("whitegrid")
sns.set_palette("husl")

print("✓ Plotting defaults configured for report-ready output")
# Out:
# ✓ Plotting defaults configured for report-ready output

# %% [markdown]
# ## Step 5: Define Project Paths and Constants
#
# Set up directory structure and global constants.

# %%
# Project paths
PROJECT_ROOT = os.path.abspath('.')
DATA_DIR = os.path.join(PROJECT_ROOT, 'data')
FIGURES_DIR = os.path.join(PROJECT_ROOT, 'figures')

# Ensure directories exist
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(FIGURES_DIR, exist_ok=True)

# Global random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

print(f"✓ Project directories:")
print(f"  - Data:    {DATA_DIR}")
print(f"  - Figures: {FIGURES_DIR}")
print(f"\n✓ Random seed set to {RANDOM_SEED} for reproducibility")
# Out:
# ✓ Project directories:
#   - Data:    /workspaces/AgriTwin-GH/feature_demos/data
#   - Figures: /workspaces/AgriTwin-GH/feature_demos/figures
#
# ✓ Random seed set to 42 for reproducibility

# %% [markdown]
# ## Step 6: Test Basic Functionality
#
# Quick sanity check with a simple plot.

# %%
# Create a simple test plot
fig, ax = plt.subplots(figsize=(8, 4))
x = np.linspace(0, 10, 100)
y = np.sin(x)
ax.plot(x, y, label='Test Signal')
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude')
ax.set_title('Setup Verification: Basic Plot Test')
ax.legend()
plt.tight_layout()
plt.show()

print("✓ Matplotlib plotting works correctly")
# Out:
# ✓ Matplotlib plotting works correctly

# %% [markdown]
# ---
#
# ## Report Notes
#
# **Notebook 01 Deliverables:**
# - ✓ All required packages installed and verified
# - ✓ Package versions documented for reproducibility
# - ✓ Project structure initialized (data/ and figures/ directories)
# - ✓ Plotting defaults configured for publication-quality output
# - ✓ Random seed set to ensure deterministic results
#
# **Next Steps:** Proceed to Notebook 02 to generate synthetic greenhouse sensor data.
